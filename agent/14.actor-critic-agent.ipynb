# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.dates as md
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1366900

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_actor, output_size)

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            feed_critic = tf.layers.dense(feed_critic, output_size, activation = tf.nn.relu) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                state = next_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-4d828656bd02>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /Users/bochmann/lib/anaconda3/envs/gcstf/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# epoch: 10, total rewards: 5353.919974.3, cost: 499236864000.000000, total money: 12316.950004
# epoch: 20, total rewards: 1819.796145.3, cost: 141231493480448.000000, total money: 11819.796145
# epoch: 30, total rewards: -37.285290.3, cost: 21160771291447296.000000, total money: 8441.814686
# epoch: 40, total rewards: 510.785523.3, cost: 279602886365675520.000000, total money: 8991.505494
# epoch: 50, total rewards: 2303.989687.3, cost: 2872145611082606575616.000000, total money: 9287.559634
# epoch: 60, total rewards: 288.860789.3, cost: 2505784800678248448.000000, total money: 7228.140819
# epoch: 70, total rewards: 6713.725396.3, cost: nan, total money: 2666.655449
# epoch: 80, total rewards: 6067.124941.3, cost: nan, total money: 3632.825015
# epoch: 90, total rewards: 3538.124620.3, cost: nan, total money: 10523.314562
# epoch: 100, total rewards: 6177.575077.3, cost: nan, total money: 5289.015141
# epoch: 110, total rewards: 4214.049983.3, cost: nan, total money: 6272.950008
# epoch: 120, total rewards: 2565.595213.3, cost: nan, total money: 9384.165281
# epoch: 130, total rewards: 7284.025325.3, cost: nan, total money: 17284.025325
# epoch: 140, total rewards: 5462.015621.3, cost: nan, total money: 6145.545650
# epoch: 150, total rewards: 4909.839961.3, cost: nan, total money: 3836.119990
# epoch: 160, total rewards: 2533.860352.3, cost: nan, total money: 10976.900391
# epoch: 170, total rewards: 2971.279959.3, cost: nan, total money: 9870.249930
# epoch: 180, total rewards: 5055.755314.3, cost: nan, total money: 6129.265323
# epoch: 190, total rewards: 4219.694090.3, cost: nan, total money: 6473.034057
# epoch: 200, total rewards: 1371.279964.3, cost: nan, total money: 9851.999935

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 2: buy 1 unit at price 762.020020, total balance 8469.279968
# day 9: buy 1 unit at price 758.489990, total balance 7710.789978
# day 12: buy 1 unit at price 760.539978, total balance 6950.250000
# day 15, sell 1 unit at price 760.989990, investment -1.002995 %, total balance 7711.239990,
# day 18, sell 1 unit at price 770.840027, investment 1.157451 %, total balance 8482.080017,
# day 19, sell 1 unit at price 758.039978, investment -0.059330 %, total balance 9240.119995,
# day 20, sell 1 unit at price 747.919983, investment -1.659347 %, total balance 9988.039978,
# day 24: buy 1 unit at price 771.190002, total balance 9216.849976
# day 27, sell 1 unit at price 789.270020, investment 2.344431 %, total balance 10006.119996,
# day 29: buy 1 unit at price 797.070007, total balance 9209.049989
# day 31: buy 1 unit at price 790.799988, total balance 8418.250001
# day 40, sell 1 unit at price 771.820007, investment -3.167852 %, total balance 9190.070008,
# day 41: buy 1 unit at price 786.140015, total balance 8403.929993
# day 42: buy 1 unit at price 786.900024, total balance 7617.029969
# day 44, sell 1 unit at price 806.150024, investment 1.941077 %, total balance 8423.179993,
# day 47, sell 1 unit at price 807.909973, investment 2.769221 %, total balance 9231.089966,
# day 50: buy 1 unit at price 804.609985, total balance 8426.479981
# day 52: buy 1 unit at price 802.174988, total balance 7624.304993
# day 53, sell 1 unit at price 805.020020, investment 2.302706 %, total balance 8429.325013,
# day 54, sell 1 unit at price 819.309998, investment 1.826974 %, total balance 9248.635011,
# day 55: buy 1 unit at price 823.869995, total balance 8424.765016
# day 59: buy 1 unit at price 802.320007, total balance 7622.445009
# day 65, sell 1 unit at price 806.969971, investment 0.597748 %, total balance 8429.414980,
# day 73: buy 1 unit at price 828.070007, total balance 7601.344973
# day 75: buy 1 unit at price 830.760010, total balance 6770.584963
# day 81, sell 1 unit at price 830.630005, investment 0.820519 %, total balance 7601.214968,
# day 83, sell 1 unit at price 827.780029, investment 3.173300 %, total balance 8428.994997,
# day 88: buy 1 unit at price 845.539978, total balance 7583.455019
# day 89: buy 1 unit at price 845.619995, total balance 6737.835024
# day 91, sell 1 unit at price 848.780029, investment 2.500999 %, total balance 7586.615053,
# day 93, sell 1 unit at price 848.400024, investment 2.123359 %, total balance 8435.015077,
# day 94, sell 1 unit at price 830.460022, investment -1.783470 %, total balance 9265.475099,
# day 96: buy 1 unit at price 817.580017, total balance 8447.895082
# day 97: buy 1 unit at price 814.429993, total balance 7633.465089
# day 98, sell 1 unit at price 819.510010, investment -3.087674 %, total balance 8452.975099,
# day 101, sell 1 unit at price 831.500000, investment 1.702584 %, total balance 9284.475099,
# day 102: buy 1 unit at price 829.559998, total balance 8454.915101
# day 103, sell 1 unit at price 838.549988, investment 2.961580 %, total balance 9293.465089,
# day 109: buy 1 unit at price 823.349976, total balance 8470.115113
# day 110, sell 1 unit at price 824.320007, investment -0.631659 %, total balance 9294.435120,
# day 115: buy 1 unit at price 841.650024, total balance 8452.785096
# day 125, sell 1 unit at price 931.659973, investment 13.154794 %, total balance 9384.445069,
# day 126: buy 1 unit at price 927.130005, total balance 8457.315064
# day 127: buy 1 unit at price 934.299988, total balance 7523.015076
# day 129, sell 1 unit at price 928.780029, investment 10.352285 %, total balance 8451.795105,
# day 136: buy 1 unit at price 934.010010, total balance 7517.785095
# day 140: buy 1 unit at price 969.539978, total balance 6548.245117
# day 141, sell 1 unit at price 971.469971, investment 4.782497 %, total balance 7519.715088,
# day 143, sell 1 unit at price 964.859985, investment 3.270898 %, total balance 8484.575073,
# day 154, sell 1 unit at price 942.309998, investment 0.888640 %, total balance 9426.885071,
# day 157: buy 1 unit at price 950.630005, total balance 8476.255066
# day 158, sell 1 unit at price 959.450012, investment -1.040696 %, total balance 9435.705078,
# day 159: buy 1 unit at price 957.090027, total balance 8478.615051
# day 163, sell 1 unit at price 940.489990, investment -1.066663 %, total balance 9419.105041,
# day 165, sell 1 unit at price 908.729980, investment -5.052821 %, total balance 10327.835021,
# day 170: buy 1 unit at price 928.799988, total balance 9399.035033
# day 172: buy 1 unit at price 943.830017, total balance 8455.205016
# day 173: buy 1 unit at price 947.159973, total balance 7508.045043
# day 174: buy 1 unit at price 955.989990, total balance 6552.055053
# day 176, sell 1 unit at price 965.400024, investment 3.940572 %, total balance 7517.455077,
# day 179: buy 1 unit at price 972.919983, total balance 6544.535094
# day 194: buy 1 unit at price 914.390015, total balance 5630.145079
# day 197, sell 1 unit at price 926.960022, investment -1.787398 %, total balance 6557.105101,
# day 205, sell 1 unit at price 913.809998, investment -3.521050 %, total balance 7470.915099,
# day 206: buy 1 unit at price 921.289978, total balance 6549.625121
# day 215: buy 1 unit at price 932.070007, total balance 5617.555114
# day 226, sell 1 unit at price 944.489990, investment -1.202941 %, total balance 6562.045104,
# day 227, sell 1 unit at price 949.500000, investment -2.407185 %, total balance 7511.545104,
# day 229: buy 1 unit at price 953.270020, total balance 6558.275084
# day 231, sell 1 unit at price 951.679993, investment 4.078126 %, total balance 7509.955077,
# day 236: buy 1 unit at price 989.250000, total balance 6520.705077
# day 237: buy 1 unit at price 987.830017, total balance 5532.875060
# day 238: buy 1 unit at price 989.679993, total balance 4543.195067
# day 240, sell 1 unit at price 992.179993, investment 7.694647 %, total balance 5535.375060,
# day 244, sell 1 unit at price 968.450012, investment 3.903141 %, total balance 6503.825072,
# day 245: buy 1 unit at price 970.539978, total balance 5533.285094
# day 246, sell 1 unit at price 973.330017, investment 2.104335 %, total balance 6506.615111,
# day 248: buy 1 unit at price 1019.270020, total balance 5487.345091
# day 258: buy 1 unit at price 1028.069946, total balance 4459.275145
# day 260, sell 1 unit at price 1026.000000, investment 3.714936 %, total balance 5485.275145,
# day 264: buy 1 unit at price 1018.380005, total balance 4466.895140
# day 267: buy 1 unit at price 1040.609985, total balance 3426.285155
# day 272: buy 1 unit at price 1010.169983, total balance 2416.115172
# day 279: buy 1 unit at price 1040.479980, total balance 1375.635192
# day 280, sell 1 unit at price 1040.609985, investment 5.343021 %, total balance 2416.245177,
# day 281: buy 1 unit at price 1049.150024, total balance 1367.095153
# day 282, sell 1 unit at price 1064.189941, investment 7.528691 %, total balance 2431.285094,
# day 283: buy 1 unit at price 1077.140015, total balance 1354.145079
# day 293: buy 1 unit at price 1082.479980, total balance 271.665099
# day 294, sell 1 unit at price 1086.400024, investment 11.937689 %, total balance 1358.065123,
# day 296: buy 1 unit at price 1106.939941, total balance 251.125182
# day 298, sell 1 unit at price 1102.609985, investment 8.176436 %, total balance 1353.735167,
# day 299, sell 1 unit at price 1105.520020, investment 7.533541 %, total balance 2459.255187,
# day 301, sell 1 unit at price 1121.760010, investment 10.151417 %, total balance 3581.015197,
# day 306, sell 1 unit at price 1169.969971, investment 12.431169 %, total balance 4750.985168,
# day 307, sell 1 unit at price 1164.239990, investment 15.251889 %, total balance 5915.225158,
# day 309: buy 1 unit at price 1175.839966, total balance 4739.385192
# day 315, sell 1 unit at price 1055.800049, investment 1.472404 %, total balance 5795.185241,
# day 316: buy 1 unit at price 1080.599976, total balance 4714.585265
# day 326, sell 1 unit at price 1111.339966, investment 5.927650 %, total balance 5825.925231,
# day 327, sell 1 unit at price 1106.630005, investment 2.737805 %, total balance 6932.555236,
# day 340, sell 1 unit at price 1138.170044, investment 5.144674 %, total balance 8070.725280,
# day 346, sell 1 unit at price 1090.880005, investment -1.450841 %, total balance 9161.605285,
# day 347, sell 1 unit at price 1049.079956, investment -10.780379 %, total balance 10210.685241,
# day 350: buy 1 unit at price 1005.099976, total balance 9205.585265
# day 354, sell 1 unit at price 1013.409973, investment -6.217842 %, total balance 10218.995238,
# day 355, sell 1 unit at price 1025.140015, investment 1.993835 %, total balance 11244.135253,
# day 359: buy 1 unit at price 1031.640015, total balance 10212.495238
# day 363, sell 1 unit at price 1037.979980, investment 0.614552 %, total balance 11250.475218,
# day 369: buy 1 unit at price 1019.979980, total balance 10230.495238
# day 370: buy 1 unit at price 1021.179993, total balance 9209.315245
# day 371, sell 1 unit at price 1040.040039, investment 1.966711 %, total balance 10249.355284,
# day 377, sell 1 unit at price 1048.209961, investment 2.646935 %, total balance 11297.565245,
# day 382: buy 1 unit at price 1098.260010, total balance 10199.305235
# day 386: buy 1 unit at price 1078.589966, total balance 9120.715269
# day 394: buy 1 unit at price 1067.800049, total balance 8052.915220
# day 396: buy 1 unit at price 1119.500000, total balance 6933.415220
# day 397, sell 1 unit at price 1139.290039, investment 3.735912 %, total balance 8072.705259,
# day 399, sell 1 unit at price 1136.880005, investment 5.404282 %, total balance 9209.585264,
# day 400: buy 1 unit at price 1123.859985, total balance 8085.725279
# day 401: buy 1 unit at price 1120.869995, total balance 6964.855284
# day 406, sell 1 unit at price 1152.260010, investment 7.909717 %, total balance 8117.115294,
# day 407: buy 1 unit at price 1173.459961, total balance 6943.655333
# day 411, sell 1 unit at price 1155.479980, investment 3.213933 %, total balance 8099.135313,
# day 414: buy 1 unit at price 1103.979980, total balance 6995.155333
# day 423, sell 1 unit at price 1153.900024, investment 2.672934 %, total balance 8149.055357,
# day 425, sell 1 unit at price 1188.819946, investment 6.062251 %, total balance 9337.875303,
# day 429, sell 1 unit at price 1186.959961, investment 1.150444 %, total balance 10524.835264,
# day 430: buy 1 unit at price 1184.910034, total balance 9339.925230
# day 435: buy 1 unit at price 1238.500000, total balance 8101.425230
# day 442: buy 1 unit at price 1242.219971, total balance 6859.205259
# day 444, sell 1 unit at price 1249.099976, investment 13.145166 %, total balance 8108.305235,
# day 446, sell 1 unit at price 1235.010010, investment 4.228167 %, total balance 9343.315245,
# day 449, sell 1 unit at price 1206.489990, investment -2.584579 %, total balance 10549.805235,
# day 451: buy 1 unit at price 1207.770020, total balance 9342.035215
# day 453, sell 1 unit at price 1207.329956, investment -2.808683 %, total balance 10549.365171,
# day 454: buy 1 unit at price 1205.380005, total balance 9343.985166
# day 457: buy 1 unit at price 1231.150024, total balance 8112.835142
# day 461: buy 1 unit at price 1197.000000, total balance 6915.835142
# day 465: buy 1 unit at price 1164.640015, total balance 5751.195127
# day 468, sell 1 unit at price 1175.329956, investment -2.685947 %, total balance 6926.525083,
# day 473, sell 1 unit at price 1186.869995, investment -1.535616 %, total balance 8113.395078,
# day 474: buy 1 unit at price 1166.089966, total balance 6947.305112
# day 476: buy 1 unit at price 1184.650024, total balance 5762.655088
# day 482: buy 1 unit at price 1202.949951, total balance 4559.705137
# day 487: buy 1 unit at price 1081.219971, total balance 3478.485166
# day 488, sell 1 unit at price 1079.319946, investment -12.332378 %, total balance 4557.805112,
# day 490, sell 1 unit at price 1092.250000, investment -8.751044 %, total balance 5650.055112,
# day 494: buy 1 unit at price 1096.459961, total balance 4553.595151
# day 495: buy 1 unit at price 1101.160034, total balance 3452.435117
# day 496: buy 1 unit at price 1103.689941, total balance 2348.745176
# day 499, sell 1 unit at price 1071.469971, investment -7.999901 %, total balance 3420.215147,
# day 505: buy 1 unit at price 1040.089966, total balance 2380.125181
# day 506, sell 1 unit at price 1055.810059, investment -9.457238 %, total balance 3435.935240,
# day 507, sell 1 unit at price 1093.390015, investment -7.703542 %, total balance 4529.325255,
# day 508: buy 1 unit at price 1082.400024, total balance 3446.925231
# day 510, sell 1 unit at price 1038.630005, investment -13.659749 %, total balance 4485.555236,
# day 512: buy 1 unit at price 1043.660034, total balance 3441.895202
# day 514, sell 1 unit at price 1061.489990, investment -1.824789 %, total balance 4503.385192,
# day 515, sell 1 unit at price 1020.000000, investment -6.973347 %, total balance 5523.385192,
# day 516, sell 1 unit at price 1025.760010, investment -6.847327 %, total balance 6549.145202,
# day 519: buy 1 unit at price 1048.619995, total balance 5500.525207
# day 521: buy 1 unit at price 1086.229980, total balance 4414.295227
# day 523: buy 1 unit at price 1094.430054, total balance 3319.865173
# day 525, sell 1 unit at price 1050.819946, investment -4.790294 %, total balance 4370.685119,
# day 526: buy 1 unit at price 1068.729980, total balance 3301.955139
# day 531: buy 1 unit at price 1061.900024, total balance 2240.055115
# day 532: buy 1 unit at price 1042.099976, total balance 1197.955139
# day 535: buy 1 unit at price 1023.010010, total balance 174.945129
# day 545, sell 1 unit at price 1070.709961, investment 2.943976 %, total balance 1245.655090,
# day 546: buy 1 unit at price 1068.390015, total balance 177.265075
# day 547, sell 1 unit at price 1076.280029, investment -0.565410 %, total balance 1253.545104,
# day 548: buy 1 unit at price 1074.660034, total balance 178.885070
# day 553, sell 1 unit at price 1080.969971, investment 3.574913 %, total balance 1259.855041,
# day 559: buy 1 unit at price 1090.989990, total balance 168.865051
# day 566, sell 1 unit at price 1145.989990, investment 9.285537 %, total balance 1314.855041,
# day 569, sell 1 unit at price 1095.060059, investment 0.812911 %, total balance 2409.915100,
# day 570, sell 1 unit at price 1095.010010, investment 0.052992 %, total balance 3504.925110,
# day 572, sell 1 unit at price 1120.160034, investment 4.812259 %, total balance 4625.085144,
# day 573: buy 1 unit at price 1121.670044, total balance 3503.415100
# day 582, sell 1 unit at price 1119.920044, investment 5.463793 %, total balance 4623.335144,
# day 583: buy 1 unit at price 1140.989990, total balance 3482.345154
# day 586, sell 1 unit at price 1157.859985, investment 11.108340 %, total balance 4640.205139,
# day 590, sell 1 unit at price 1193.199951, investment 16.636195 %, total balance 5833.405090,
# day 591: buy 1 unit at price 1193.319946, total balance 4640.085144
# day 592: buy 1 unit at price 1185.550049, total balance 3454.535095
# day 593: buy 1 unit at price 1184.459961, total balance 2270.075134
# day 595: buy 1 unit at price 1198.849976, total balance 1071.225158
# day 596, sell 1 unit at price 1223.969971, investment 14.562094 %, total balance 2295.195129,
# day 598, sell 1 unit at price 1205.500000, investment 12.175010 %, total balance 3500.695129,
# day 599, sell 1 unit at price 1193.000000, investment 9.350224 %, total balance 4693.695129,
# day 600, sell 1 unit at price 1184.619995, investment 5.612163 %, total balance 5878.315124,
# day 601: buy 1 unit at price 1173.020020, total balance 4705.295104
# day 602: buy 1 unit at price 1168.489990, total balance 3536.805114
# day 604: buy 1 unit at price 1194.430054, total balance 2342.375060
# day 606: buy 1 unit at price 1205.920044, total balance 1136.455016
# day 614, sell 1 unit at price 1221.099976, investment 7.021095 %, total balance 2357.554992,
# day 617: buy 1 unit at price 1236.369995, total balance 1121.184997
# day 618, sell 1 unit at price 1248.839966, investment 4.652568 %, total balance 2370.024963,
# day 619, sell 1 unit at price 1264.550049, investment 6.663574 %, total balance 3634.575012,
# day 620: buy 1 unit at price 1256.000000, total balance 2378.575012
# day 624, sell 1 unit at price 1188.479980, investment 0.339397 %, total balance 3567.054992,
# day 625: buy 1 unit at price 1168.079956, total balance 2398.975036
# day 627: buy 1 unit at price 1185.400024, total balance 1213.575012
# day 636: buy 1 unit at price 1178.979980, total balance 34.595032
# day 643, sell 1 unit at price 1134.150024, investment -5.396835 %, total balance 1168.745056,
# day 644, sell 1 unit at price 1116.459961, investment -4.821747 %, total balance 2285.205017,
# day 653, sell 1 unit at price 1078.719971, investment -7.682566 %, total balance 3363.924988,
# day 659, sell 1 unit at price 1102.329956, investment -7.710799 %, total balance 4466.254944,
# day 661, sell 1 unit at price 1121.880005, investment -6.968956 %, total balance 5588.134949,
# day 663, sell 1 unit at price 1086.349976, investment -12.133910 %, total balance 6674.484925,
# day 665: buy 1 unit at price 1076.010010, total balance 5598.474915
# day 668: buy 1 unit at price 1111.250000, total balance 4487.224915
# day 675, sell 1 unit at price 1144.900024, investment -8.845539 %, total balance 5632.124939,
# day 678, sell 1 unit at price 1146.349976, investment -1.860316 %, total balance 6778.474915,
# day 681, sell 1 unit at price 1138.069946, investment -3.992752 %, total balance 7916.544861,
# day 684, sell 1 unit at price 1132.119995, investment -3.974621 %, total balance 9048.664856,
# day 686, sell 1 unit at price 1239.410034, investment 15.185735 %, total balance 10288.074890,
# day 697: buy 1 unit at price 1197.270020, total balance 9090.804870
# day 701, sell 1 unit at price 1198.449951, investment 7.847015 %, total balance 10289.254821,
# day 705, sell 1 unit at price 1151.290039, investment -3.840402 %, total balance 11440.544860,
# day 710: buy 1 unit at price 1188.099976, total balance 10252.444884
# day 719, sell 1 unit at price 1239.560059, investment 4.331292 %, total balance 11492.004943,
# day 722: buy 1 unit at price 1232.410034, total balance 10259.594909
# day 724: buy 1 unit at price 1229.930054, total balance 9029.664855
# day 725: buy 1 unit at price 1234.030029, total balance 7795.634826
# day 729, sell 1 unit at price 1225.089966, investment -0.593964 %, total balance 9020.724792,
# day 730, sell 1 unit at price 1219.000000, investment -0.888673 %, total balance 10239.724792,
# day 734: buy 1 unit at price 1209.000000, total balance 9030.724792
# day 736: buy 1 unit at price 1189.130005, total balance 7841.594787
# day 740, sell 1 unit at price 1217.140015, investment -1.368687 %, total balance 9058.734802,
# day 741, sell 1 unit at price 1243.010010, investment 2.813069 %, total balance 10301.744812,
# day 750: buy 1 unit at price 1290.000000, total balance 9011.744812
# day 751: buy 1 unit at price 1262.619995, total balance 7749.124817
# day 753, sell 1 unit at price 1260.109985, investment 5.969068 %, total balance 9009.234802,
# day 756: buy 1 unit at price 1292.030029, total balance 7717.204773
# day 758, sell 1 unit at price 1308.859985, investment 1.462014 %, total balance 9026.064758,
# day 762: buy 1 unit at price 1298.000000, total balance 7728.064758
# day 765, sell 1 unit at price 1320.699951, investment 4.599955 %, total balance 9048.764709,
# day 766, sell 1 unit at price 1315.459961, investment 1.813420 %, total balance 10364.224670,
# day 768, sell 1 unit at price 1301.349976, investment 0.258088 %, total balance 11665.574646,
# day 779: buy 1 unit at price 1343.560059, total balance 10322.014587
# day 782: buy 1 unit at price 1350.270020, total balance 8971.744567
# day 790: buy 1 unit at price 1343.560059, total balance 7628.184508
# day 791, sell 1 unit at price 1360.400024, investment 1.253384 %, total balance 8988.584532,
# day 794, sell 1 unit at price 1337.020020, investment -0.981285 %, total balance 10325.604552,
# day 796, sell 1 unit at price 1360.660034, investment 1.272736 %, total balance 11686.264586,
# day 805: buy 1 unit at price 1451.699951, total balance 10234.564635
# day 808, sell 1 unit at price 1485.949951, investment 2.359303 %, total balance 11720.514586,
# day 811: buy 1 unit at price 1433.900024, total balance 10286.614562
# day 813, sell 1 unit at price 1458.630005, investment 1.724666 %, total balance 11745.244567,
# day 820: buy 1 unit at price 1479.229980, total balance 10266.014587
# day 823: buy 1 unit at price 1518.270020, total balance 8747.744567
# day 824: buy 1 unit at price 1514.660034, total balance 7233.084533
# day 826: buy 1 unit at price 1519.670044, total balance 5713.414489
# day 829, sell 1 unit at price 1485.109985, investment 0.397504 %, total balance 7198.524474,
# day 832: buy 1 unit at price 1393.180054, total balance 5805.344420
# day 834: buy 1 unit at price 1339.329956, total balance 4466.014464
# day 835, sell 1 unit at price 1389.109985, investment -8.507053 %, total balance 5855.124449,
# day 836: buy 1 unit at price 1341.390015, total balance 4513.734434
# day 837, sell 1 unit at price 1386.520020, investment -8.459985 %, total balance 5900.254454,
# day 838: buy 1 unit at price 1319.040039, total balance 4581.214415
# day 840: buy 1 unit at price 1215.560059, total balance 3365.654356
# day 846: buy 1 unit at price 1119.800049, total balance 2245.854307
# day 848, sell 1 unit at price 1115.290039, investment -26.609724 %, total balance 3361.144346,
# day 849, sell 1 unit at price 1072.319946, investment -23.030771 %, total balance 4433.464292,
# day 853: buy 1 unit at price 1161.750000, total balance 3271.714292
# day 854: buy 1 unit at price 1110.709961, total balance 2161.004331
# day 855, sell 1 unit at price 1146.819946, investment -14.373606 %, total balance 3307.824277,
# day 861: buy 1 unit at price 1186.510010, total balance 2121.314267
# day 862, sell 1 unit at price 1210.280029, investment -9.774188 %, total balance 3331.594296,
# day 864, sell 1 unit at price 1217.560059, investment -7.693472 %, total balance 4549.154355,
# day 874, sell 1 unit at price 1275.880005, investment 4.962317 %, total balance 5825.034360,
# day 876, sell 1 unit at price 1341.479980, investment 19.796385 %, total balance 7166.514340,
# day 877: buy 1 unit at price 1348.660034, total balance 5817.854306
# day 882: buy 1 unit at price 1372.560059, total balance 4445.294247
# day 887: buy 1 unit at price 1356.130005, total balance 3089.164242
# day 892, sell 1 unit at price 1402.800049, investment 20.748874 %, total balance 4491.964291,
# day 894, sell 1 unit at price 1417.020020, investment 27.577862 %, total balance 5908.984311,
# day 896, sell 1 unit at price 1416.729980, investment 19.403121 %, total balance 7325.714291,
# day 897: buy 1 unit at price 1428.920044, total balance 5896.794247
# day 898: buy 1 unit at price 1431.819946, total balance 4464.974301
# day 901, sell 1 unit at price 1412.180054, investment 4.709862 %, total balance 5877.154355,
# day 902, sell 1 unit at price 1438.390015, investment 4.796144 %, total balance 7315.544370,
# day 907: buy 1 unit at price 1413.180054, total balance 5902.364316
# day 911, sell 1 unit at price 1435.959961, investment 5.886601 %, total balance 7338.324277,
# day 912: buy 1 unit at price 1431.719971, total balance 5906.604306
# day 916: buy 1 unit at price 1441.329956, total balance 4465.274350
# day 917, sell 1 unit at price 1359.900024, investment -4.830223 %, total balance 5825.174374,
# day 920: buy 1 unit at price 1438.040039, total balance 4387.134335
# day 924: buy 1 unit at price 1496.000000, total balance 2891.134335
# day 928: buy 1 unit at price 1520.579956, total balance 1370.554379
# day 958, sell 1 unit at price 1608.219971, investment 12.319987 %, total balance 2978.774350,
# day 960: buy 1 unit at price 1634.329956, total balance 1344.444394
# day 971, sell 1 unit at price 1519.280029, investment 7.507888 %, total balance 2863.724423,

# %%
dates = pd.to_datetime(df['Date'])
fig = plt.figure(figsize = (15,5))
plt.gcf().autofmt_xdate()
myFmt = md.DateFormatter('%Y-%m-%d')
plt.gca().xaxis.set_major_formatter(myFmt)
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
