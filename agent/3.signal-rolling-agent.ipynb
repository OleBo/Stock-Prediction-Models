# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as md
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1366900

# %%
def buy_stock(
    real_movement,
    delay = 5,
    initial_state = 1,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    delay_change_decision = delay
    current_decision = 0
    state = initial_state
    current_val = real_movement[0]
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    if state == 1:
        initial_money, current_inventory = buy(
            0, initial_money, current_inventory
        )

    for i in range(1, real_movement.shape[0], 1):
        if real_movement[i] < current_val and state == 0:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 1
                initial_money, current_inventory = buy(
                    i, initial_money, current_inventory
                )
                current_decision = 0
                states_buy.append(i)
        if real_movement[i] > current_val and state == 1:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 0

                if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
                else:
                    if current_inventory > max_sell:
                        sell_units = max_sell
                    else:
                        sell_units = current_inventory
                    current_inventory -= sell_units
                    total_sell = sell_units * real_movement[i]
                    initial_money += total_sell
                    try:
                        invest = (
                            (real_movement[i] - real_movement[states_buy[-1]])
                            / real_movement[states_buy[-1]]
                        ) * 100
                    except:
                        invest = 0
                    print(
                        'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                        % (i, sell_units, total_sell, invest, initial_money)
                    )

                current_decision = 0
                states_sell.append(i)
        current_val = real_movement[i]
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, initial_state = 1, 
                                                         delay = 3, initial_money = 10000)
# Out:
# day 0: buy 1 units at price 768.700012, total balance 9231.299988
# day 10, sell 1 units at price 764.479980, investment -0.548983 %, total balance 9995.779968,
# day 19: buy 1 units at price 758.039978, total balance 9237.739990
# day 25, sell 1 units at price 776.419983, investment 2.424675 %, total balance 10014.159973,
# day 35: buy 1 units at price 791.260010, total balance 9222.899963
# day 43, sell 1 units at price 794.020020, investment 0.348812 %, total balance 10016.919983,
# day 52: buy 1 units at price 802.174988, total balance 9214.744995
# day 56, sell 1 units at price 835.669983, investment 4.175522 %, total balance 10050.414978,
# day 60: buy 1 units at price 796.789978, total balance 9253.625000
# day 66, sell 1 units at price 808.380005, investment 1.454590 %, total balance 10062.005005,
# day 79: buy 1 units at price 823.210022, total balance 9238.794983
# day 86, sell 1 units at price 838.679993, investment 1.879225 %, total balance 10077.474976,
# day 96: buy 1 units at price 817.580017, total balance 9259.894959
# day 101, sell 1 units at price 831.500000, investment 1.702584 %, total balance 10091.394959,
# day 106: buy 1 units at price 827.880005, total balance 9263.514954
# day 114, sell 1 units at price 838.210022, investment 1.247767 %, total balance 10101.724976,
# day 129: buy 1 units at price 928.780029, total balance 9172.944947
# day 133, sell 1 units at price 943.000000, investment 1.531038 %, total balance 10115.944947,
# day 150: buy 1 units at price 949.830017, total balance 9166.114930
# day 160, sell 1 units at price 965.590027, investment 1.659245 %, total balance 10131.704957,
# day 165: buy 1 units at price 908.729980, total balance 9222.974977
# day 171, sell 1 units at price 930.090027, investment 2.350538 %, total balance 10153.065004,
# day 182: buy 1 units at price 947.799988, total balance 9205.265016
# day 190, sell 1 units at price 929.359985, investment -1.945558 %, total balance 10134.625001,
# day 196: buy 1 units at price 922.219971, total balance 9212.405030
# day 206, sell 1 units at price 921.289978, investment -0.100843 %, total balance 10133.695008,
# day 213: buy 1 units at price 926.500000, total balance 9207.195008
# day 220, sell 1 units at price 921.809998, investment -0.506206 %, total balance 10129.005006,
# day 231: buy 1 units at price 951.679993, total balance 9177.325013
# day 238, sell 1 units at price 989.679993, investment 3.992939 %, total balance 10167.005006,
# day 249: buy 1 units at price 1017.109985, total balance 9149.895021
# day 255, sell 1 units at price 1033.329956, investment 1.594712 %, total balance 10183.224977,
# day 261: buy 1 units at price 1020.909973, total balance 9162.315004
# day 267, sell 1 units at price 1040.609985, investment 1.929652 %, total balance 10202.924989,
# day 272: buy 1 units at price 1010.169983, total balance 9192.755006
# day 277, sell 1 units at price 1037.050049, investment 2.660945 %, total balance 10229.805055,
# day 286: buy 1 units at price 1063.630005, total balance 9166.175050
# day 295, sell 1 units at price 1102.229980, investment 3.629079 %, total balance 10268.405030,
# day 303: buy 1 units at price 1129.790039, total balance 9138.614991
# day 308, sell 1 units at price 1170.369995, investment 3.591814 %, total balance 10308.984986,
# day 314: buy 1 units at price 1111.900024, total balance 9197.084962
# day 321, sell 1 units at price 1052.099976, investment -5.378186 %, total balance 10249.184938,
# day 332: buy 1 units at price 1069.520020, total balance 9179.664918
# day 336, sell 1 units at price 1109.640015, investment 3.751215 %, total balance 10289.304933,
# day 345: buy 1 units at price 1097.709961, total balance 9191.594972
# day 355, sell 1 units at price 1025.140015, investment -6.611031 %, total balance 10216.734987,
# day 365: buy 1 units at price 1072.079956, total balance 9144.655031
# day 374, sell 1 units at price 1037.310059, investment -3.243219 %, total balance 10181.965090,
# day 384: buy 1 units at price 1079.229980, total balance 9102.735110
# day 394, sell 1 units at price 1067.800049, investment -1.059082 %, total balance 10170.535159,
# day 404: buy 1 units at price 1134.790039, total balance 9035.745120
# day 409, sell 1 units at price 1169.839966, investment 3.088671 %, total balance 10205.585086,
# day 413: buy 1 units at price 1118.459961, total balance 9087.125125
# day 419, sell 1 units at price 1124.270020, investment 0.519470 %, total balance 10211.395145,
# day 429: buy 1 units at price 1186.959961, total balance 9024.435184
# day 434, sell 1 units at price 1268.329956, investment 6.855328 %, total balance 10292.765140,
# day 440: buy 1 units at price 1223.709961, total balance 9069.055179
# day 444, sell 1 units at price 1249.099976, investment 2.074839 %, total balance 10318.155155,
# day 449: buy 1 units at price 1206.489990, total balance 9111.665165
# day 456, sell 1 units at price 1241.819946, investment 2.928326 %, total balance 10353.485111,
# day 461: buy 1 units at price 1197.000000, total balance 9156.485111
# day 472, sell 1 units at price 1171.089966, investment -2.164581 %, total balance 10327.575077,
# day 483: buy 1 units at price 1168.189941, total balance 9159.385136
# day 495, sell 1 units at price 1101.160034, investment -5.737929 %, total balance 10260.545170,
# day 503: buy 1 units at price 1070.000000, total balance 9190.545170
# day 513, sell 1 units at price 1064.709961, investment -0.494396 %, total balance 10255.255131,
# day 520: buy 1 units at price 1044.410034, total balance 9210.845097
# day 524, sell 1 units at price 1106.430054, investment 5.938283 %, total balance 10317.275151,
# day 532: buy 1 units at price 1042.099976, total balance 9275.175175
# day 543, sell 1 units at price 1045.849976, investment 0.359850 %, total balance 10321.025151,
# day 549: buy 1 units at price 1070.329956, total balance 9250.695195
# day 555, sell 1 units at price 1098.260010, investment 2.609481 %, total balance 10348.955205,
# day 561: buy 1 units at price 1060.619995, total balance 9288.335210
# day 566, sell 1 units at price 1145.989990, investment 8.049065 %, total balance 10434.325200,
# day 570: buy 1 units at price 1095.010010, total balance 9339.315190
# day 578, sell 1 units at price 1110.369995, investment 1.402726 %, total balance 10449.685185,
# day 588: buy 1 units at price 1142.319946, total balance 9307.365239
# day 595, sell 1 units at price 1198.849976, investment 4.948704 %, total balance 10506.215215,
# day 601: buy 1 units at price 1173.020020, total balance 9333.195195
# day 606, sell 1 units at price 1205.920044, investment 2.804728 %, total balance 10539.115239,
# day 620: buy 1 units at price 1256.000000, total balance 9283.115239
# day 627, sell 1 units at price 1185.400024, investment -5.621017 %, total balance 10468.515263,
# day 633: buy 1 units at price 1132.030029, total balance 9336.485234
# day 640, sell 1 units at price 1151.420044, investment 1.712853 %, total balance 10487.905278,
# day 646: buy 1 units at price 1103.630005, total balance 9384.275273
# day 652, sell 1 units at price 1080.380005, investment -2.106684 %, total balance 10464.655278,
# day 659: buy 1 units at price 1102.329956, total balance 9362.325322
# day 667, sell 1 units at price 1097.949951, investment -0.397341 %, total balance 10460.275273,
# day 680: buy 1 units at price 1130.099976, total balance 9330.175297
# day 692, sell 1 units at price 1169.949951, investment 3.526234 %, total balance 10500.125248,
# day 702: buy 1 units at price 1182.689941, total balance 9317.435307
# day 709, sell 1 units at price 1192.849976, investment 0.859062 %, total balance 10510.285283,
# day 715: buy 1 units at price 1204.410034, total balance 9305.875249
# day 719, sell 1 units at price 1239.560059, investment 2.918443 %, total balance 10545.435308,
# day 726: buy 1 units at price 1218.760010, total balance 9326.675298
# day 737, sell 1 units at price 1202.310059, investment -1.349728 %, total balance 10528.985357,
# day 752: buy 1 units at price 1261.290039, total balance 9267.695318
# day 758, sell 1 units at price 1308.859985, investment 3.771531 %, total balance 10576.555303,
# day 765: buy 1 units at price 1320.699951, total balance 9255.855352
# day 776, sell 1 units at price 1320.540039, investment -0.012108 %, total balance 10576.395391,
# day 788: buy 1 units at price 1349.589966, total balance 9226.805425
# day 797, sell 1 units at price 1394.209961, investment 3.306189 %, total balance 10621.015386,
# day 811: buy 1 units at price 1433.900024, total balance 9187.115362
# day 818, sell 1 units at price 1448.229980, investment 0.999369 %, total balance 10635.345342,
# day 829: buy 1 units at price 1485.109985, total balance 9150.235357
# day 837, sell 1 units at price 1386.520020, investment -6.638563 %, total balance 10536.755377,
# day 842: buy 1 units at price 1215.410034, total balance 9321.345343
# day 851, sell 1 units at price 1134.459961, investment -6.660310 %, total balance 10455.805304,
# day 859: buy 1 units at price 1097.880005, total balance 9357.925299
# day 864, sell 1 units at price 1217.560059, investment 10.901014 %, total balance 10575.485358,
# day 874: buy 1 units at price 1275.880005, total balance 9299.605353
# day 880, sell 1 units at price 1351.109985, investment 5.896321 %, total balance 10650.715338,
# day 890: buy 1 units at price 1373.484985, total balance 9277.230353
# day 895, sell 1 units at price 1417.839966, investment 3.229375 %, total balance 10695.070319,
# day 906: buy 1 units at price 1403.839966, total balance 9291.230353
# day 910, sell 1 units at price 1451.119995, investment 3.367907 %, total balance 10742.350348,
# day 917: buy 1 units at price 1359.900024, total balance 9382.450324
# day 921, sell 1 units at price 1464.699951, investment 7.706443 %, total balance 10847.150275,
# day 931: buy 1 units at price 1515.550049, total balance 9331.600226
# day 939, sell 1 units at price 1522.020020, investment 0.426906 %, total balance 10853.620246,
# day 946: buy 1 units at price 1494.489990, total balance 9359.130256
# day 952, sell 1 units at price 1517.979980, investment 1.571773 %, total balance 10877.110236,
# day 962: buy 1 units at price 1634.180054, total balance 9242.930182
# day 972, sell 1 units at price 1541.439941, investment -5.675024 %, total balance 10784.370123,

# %%
close = df['Close']
dates = pd.to_datetime(df['Date'])
fig = plt.figure(figsize = (15,5))
plt.gcf().autofmt_xdate()
myFmt = md.DateFormatter('%Y-%m-%d')
plt.gca().xaxis.set_major_formatter(myFmt)
plt.plot(dates,close, color='r', lw=2.,label = 'Close')
plt.plot(dates,close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(dates,close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
